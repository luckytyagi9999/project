# %%
print("================================================================")
print( "     SMARTCAMPUS UTILITY & ACCESS PASS GENERATOR               ")
print("================================================================")
import sys
a=int(input("Select User Category (1: Student, 2: Faculty/Staff):"))
if a!=1 and a!=2:
    print("error the only input is 1 or 2")
    sys.exit()
else:
  if(a==1):
      b=input("Enter Sub-Category (UG / PG):")
      b=b.upper()
      x,y='UG','PG'
      if b!=x and b!=y:
         print("error the only input is UG or PG")
         sys.exit()
      c=float(input("Enter Student CGPA (0.0 - 10.0):"))
      if not(0.0<=c<=10.0):
        print('enter only 0 to 10')
        sys.exit()
  elif(a==2):
    a=int(input("Select User Category (3:Resident Faculty, 4:Visiting / Guest Faculty):"))
    if a!=3 and a!=4:
        print('error only input is 3 or 4')
        sys.exit()
  d=int(input("Select Parking Permit (0: None, 2: Two-Wheeler, 4: Four-Wheeler):"))
  if d!=0 and d!=2 and d!=4:
    print('error only input is 0 or 2 or 4')
    sys.exit()
  e=float(input("Enter Monthly Electricity Consumption (in kWh):"))
  discount=0
  if(a==1):
    if(b=="UG"):
        base=500.00
    elif(b=="PG"):
        base=350.00
    if (c>=8.5):
        discount=base*0.2
    elif(7.5<=c<=8.49):
        discount=base*.1
  elif(a==3):
      exp=int(input("enter your service years"))
      base=800.00
      if(exp>10):
        discount=base*0.15
  elif(a==4):
    base=1200.00      
  if d==2:
    parking=200.00
    surcharge=0
  elif(d==4):
     parking=600.00
     surcharge=0
     if a==1:
        surcharge=150      
  else:
    parking=0
    surcharge=0
  if e<0:
      sys.exit("[error]: electricity can't be negetive")
  if e<=100:
    bill=e*3+50
    f=50
  elif 101<= e <=300:
    bill=e*5+100
    f=100
  elif 301<= e<=500:
    bill=e*7.50+150
    f=150
  else:
    bill=e*10+250
    f=250

  print("----------------------------------------------------------------")
  print("                 CALCULATED INVOICE BREAKDOWN                   ")
  print("----------------------------------------------------------------")
  print(f"Base Access Pass Fee : ₹{base}")
  print(f"Merit Discount : - ₹{discount}")
  print(f"Parking Fee ({d}-Wheeler) : ₹{parking}")
  if surcharge!=0:
    print(f"Student Peak Surcharge : ₹{surcharge}")
  print(f"Net Pass & Parking Total : ₹{base+parking+surcharge-discount}")
  print("----------------------------------------------------------------")
  print(f"Electricity Bill ({e} kWh) : ₹{bill}(Slab calculated + Fixed Charge ₹{f})")
  print("----------------------------------------------------------------")
  print(f"TOTAL MONTHLY PAYABLE : ₹{base+parking+surcharge-discount+bill}")
  print("================================================================")
# Out:
# ================================================================
#      SMARTCAMPUS UTILITY & ACCESS PASS GENERATOR
# ================================================================
# Select User Category (1: Student, 2: Faculty/Staff): 1
# Enter Sub-Category (UG / PG): ug
# Enter Student CGPA (0.0 - 10.0): 5
# Select Parking Permit (0: None, 2: Two-Wheeler, 4: Four-Wheeler): 5
# error only input is 0 or 2 or 4
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\Saksham\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
