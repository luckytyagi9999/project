# %%
print("================================================================")
print( "     SMARTCAMPUS UTILITY & ACCESS PASS GENERATOR               ")
print("================================================================")
a=int(input("Select User Category (1: Student, 2: Faculty/Staff):"))
while a!=1 and a!=2:
    print("ERROR: INPUT ONLY 1 OR 2")
    a= int(input("Select User Category (1: Student, 2: Faculty/Staff):"))
if(a==1):
    b=input("Enter Sub-Category (UG / PG):")
    while b!="UG" and b!="PG":
     print("ERROR:INPUT UG OR PG ONLY")
     b=input("Enter Sub-Category (UG / PG):")
    c=float(input("Enter Student CGPA (0.0 - 10.0):"))
    while c<0.0 or c>10.0:
      print("ERROR:ONLY INPUT CGPA FROM 0.0 TO 10.0")
      c=float(input("Enter Student CGPA (0.0 - 10.0):"))
elif(a==2):
    exp=int(input("enter your service years"))
    a=int(input("Select User Category (3:Resident Faculty, 4:Visiting / Guest Faculty):"))
    while a!=3 and a!=4:
       print("ERROR: INPUT ONLY 3 OR 4")
       a=int(input("Select User Category (3:Resident Faculty, 4:Visiting / Guest Faculty):"))


d=int(input("Select Parking Permit (0: None, 2: Two-Wheeler, 4: Four-Wheeler):"))
while d!=0 and d!=2 and d!=4:
    print("ERROR:ONLY 0 ,2 OR 4 IS VALID")
    d=int(input("Select Parking Permit (0: None, 2: Two-Wheeler, 4: Four-Wheeler):"))
e=float(input("Enter Monthly Electricity Consumption (in kWh):"))
discount=0
if(a==1):
    if(b=="UG"):
        base=500.00
    elif(b=="PG"):
        base=350.00
    if (c>=8.5):
        discount=base*0.2
    elif(7.<=c<=8.49):
        discount=base*.1
elif(a==3):
    base=800.00
    if(exp>10):
        discount=base*0.15
elif(a==4):
    base=1200.00
    if(exp>10):
       discount=base*0.15
         
if d==2:
    parking=200.00
    surcharge=0
elif(d==4):
     parking=600.00
     if a==1:
        surcharge=150
     else:
         surcharge=0
else:
    parking=0
    surcharge=0

if e<=100:
    bill=e*3+50
    f=50
elif 101<= e <=300:
    bill=e*5+100
    f=100
elif 301<= e<=500:
    bill=e*7.50+150
    f=150
else:
    bill=e*10+250
    f=250

print("----------------------------------------------------------------")
print("                 CALCULATED INVOICE BREAKDOWN                   ")
print("----------------------------------------------------------------")

print(f"Base Access Pass Fee : ₹{base}")
print(f"Merit Discount : - ₹{discount}")
print(f"Parking Fee ({d}-Wheeler) : ₹{parking}")
if surcharge!=0:
    print(f"Student Peak Surcharge : ₹{surcharge}")
print(f"Net Pass & Parking Total : ₹{base+parking+surcharge-discount}")
print("----------------------------------------------------------------")
print(f"Electricity Bill ({e} kWh) : ₹{bill}(Slab calculated + Fixed Charge ₹{f})")
print("----------------------------------------------------------------")
print(f"TOTAL MONTHLY PAYABLE : ₹{base+parking+surcharge-discount+bill}")
print("================================================================")
# Out:
# ...
#      SMARTCAMPUS UTILITY & ACCESS PASS GENERATOR
# ...
# Select User Category (1: Student, 2: Faculty/Staff): 2
# enter your service years 5
# Select User Category (3:Resident Faculty, 4:Visiting / Guest Faculty): 3
# Select Parking Permit (0: None, 2: Two-Wheeler, 4: Four-Wheeler): 4
# Enter Monthly Electricity Consumption (in kWh): 32
# ----------------------------------------------------------------
#                  CALCULATED INVOICE BREAKDOWN
# ----------------------------------------------------------------
# Base Access Pass Fee : ₹800.0
# Merit Discount : - ₹0
# Parking Fee (4-Wheeler) : ₹600.0
# Net Pass & Parking Total : ₹1400.0
# ----------------------------------------------------------------
# Electricity Bill (32.0 kWh) : ₹146.0(Slab calculated + Fixed Charge ₹50)
# ----------------------------------------------------------------
# TOTAL MONTHLY PAYABLE : ₹1546.0
# ...
